# %%
import warnings
import pandas as pd
warnings.filterwarnings('ignore')
from model.TCN import Train_TCN,Test_TCN
from model.CNN import Train_CNN,Test_CNN
from model.m_csa_train import*

print('done')
# Out:
# done

# %%
train_DataFrame=pd.read_excel('./data_input/论文/实验/声音/训练.xlsx',header=None)
test_DataFrame=pd.read_excel('./data_input/论文/实验/声音/滚动体_验证.xlsx',header=None)

kernel_size = 5
filter_number = 25
num_steps=40
num_epochs = 30
tcn_path_save_model='./saved_model/model/tcn_saved_model/clf.h5'
cnn_path_save_model='./saved_model/model/cnn_saved_model/clf.h5'
res_path_save_model='./saved_model/model/res_saved_model/clf.h5'
print('参数设置完成')
# Out:
# 参数设置完成

# %%
loss_tcn,acc_tcn,val_loss_tcn,val_acc_tcn=Train_TCN(train_DataFrame,tcn_path_save_model,num_epochs,kernel_size,filter_number,num_steps)
# Out:
# 40 12
# (40, 12)
# 4
# Size of receptive field:  17.0
# Epoch 1/30
# 27/27 [==============================] - 2s 33ms/step - loss: 1.4746 - accuracy: 0.2641 - val_loss: 1.3891 - val_accuracy: 0.2711
# Epoch 2/30
# 27/27 [==============================] - 1s 28ms/step - loss: 1.3827 - accuracy: 0.2838 - val_loss: 1.3721 - val_accuracy: 0.2878
# Epoch 3/30
# 27/27 [==============================] - 1s 29ms/step - loss: 1.3646 - accuracy: 0.3016 - val_loss: 1.3632 - val_accuracy: 0.2922
# Epoch 4/30
# 27/27 [==============================] - 1s 30ms/step - loss: 1.3485 - accuracy: 0.3155 - val_loss: 1.3527 - val_accuracy: 0.3011
# Epoch 5/30
# 27/27 [==============================] - 1s 31ms/step - loss: 1.3345 - accuracy: 0.3260 - val_loss: 1.3354 - val_accuracy: 0.3185
# Epoch 6/30
# 27/27 [==============================] - 1s 31ms/step - loss: 1.3067 - accuracy: 0.3578 - val_loss: 1.2959 - val_accuracy: 0.3556
# Epoch 7/30
# ...

# %%
print("TCN参数部分")
print("训练损失：",loss_tcn)
print("验证损失：",val_loss_tcn)
print("训练-准确率：",acc_tcn)
print("验证-准确率：",val_acc_tcn)
# Out:
# TCN参数部分
# 训练损失： [1.3003103733062744, 1.1588231325149536, 1.1042838096618652, 1.0900757312774658, 1.072460412979126, 1.063417911529541, 1.059913992881775, 1.0484696626663208, 1.031700611114502, 1.0163155794143677, 0.9965097308158875, 0.9879852533340454, 0.9562137722969055, 0.9279758334159851, 0.9030196070671082, 0.8807522654533386, 0.8369342088699341, 0.7955335974693298, 0.7809163928031921, 0.7323848605155945, 0.7107001543045044, 0.6932314038276672, 0.6621476411819458, 0.6181964874267578, 0.5873181819915771, 0.5800862908363342, 0.5393381714820862, 0.5535315275192261, 0.48172134160995483, 0.47944509983062744]
# ...

# %%
# path_load_model='saved_model/clf.h5'
Identification_result,number = Test_TCN(test_DataFrame,tcn_path_save_model,num_steps)
print("分类结果：",Identification_result)
print("故障种类：",number)
print(len(Identification_result))
result=Identification_result.tolist()
m=int(max(set(result)))
for i in range(0,m+1):
    print("故障类型",i,"的数量：", result.count(i))
# Out:
# 32/32 [==============================] - 0s 2ms/step
# (1019, 4)
# 分类结果： [4 4 4 ... 4 4 4]
# 故障种类： 1
# 1019
# 故障类型 0 的数量： 0
# 故障类型 1 的数量： 0
# 故障类型 2 的数量： 0
# 故障类型 3 的数量： 0
# 故障类型 4 的数量： 1019

# %%
loss_cnn,acc_cnn,val_loss_cnn,val_acc_cnn=Train_CNN(train_DataFrame,cnn_path_save_model,num_epochs,kernel_size,filter_number,num_steps)
# Out:
# 40 12
# (40, 12)
# 4
# Size of receptive field:  17.0
# Epoch 1/30
# 27/27 [==============================] - 2s 33ms/step - loss: 1.4552 - accuracy: 0.2692 - val_loss: 1.3786 - val_accuracy: 0.2824
# Epoch 2/30
# 27/27 [==============================] - 1s 28ms/step - loss: 1.3802 - accuracy: 0.2956 - val_loss: 1.3700 - val_accuracy: 0.2844
# Epoch 3/30
# 27/27 [==============================] - 1s 29ms/step - loss: 1.3659 - accuracy: 0.3026 - val_loss: 1.3632 - val_accuracy: 0.2892
# Epoch 4/30
# 27/27 [==============================] - 1s 31ms/step - loss: 1.3528 - accuracy: 0.3126 - val_loss: 1.3541 - val_accuracy: 0.2936
# Epoch 5/30
# 27/27 [==============================] - 1s 31ms/step - loss: 1.3368 - accuracy: 0.3241 - val_loss: 1.3385 - val_accuracy: 0.3079
# Epoch 6/30
# 27/27 [==============================] - 1s 31ms/step - loss: 1.3143 - accuracy: 0.3400 - val_loss: 1.3005 - val_accuracy: 0.3365
# Epoch 7/30
# ...

# %%
print("CNN参数部分")
print("训练损失：",loss_cnn)
print("验证损失：",val_loss_cnn)
print("训练-准确率：",acc_cnn)
print("验证-准确率：",val_acc_cnn)
# Out:
# CNN参数部分
# 训练损失： [1.2958910465240479, 1.1655669212341309, 1.1224768161773682, 1.0855433940887451, 1.0717401504516602, 1.0678776502609253, 1.0599370002746582, 1.0549139976501465, 1.0309499502182007, 1.0260121822357178, 1.003161072731018, 0.9866411685943604, 0.9709944128990173, 0.9396628737449646, 0.906255304813385, 0.8700535893440247, 0.846376895904541, 0.7917693853378296, 0.774789035320282, 0.7364129424095154, 0.6991039514541626, 0.661444365978241, 0.6429561972618103, 0.6207037568092346, 0.5767369866371155, 0.566169023513794, 0.5100439786911011, 0.502367377281189, 0.4826207756996155, 0.453582763671875]
# ...

# %%
# path_load_model='saved_model/clf.h5'
Identification_result,number = Test_CNN(test_DataFrame,cnn_path_save_model,num_steps)
print("分类结果：",Identification_result)
print("故障种类：",number)
print(len(Identification_result))
result=Identification_result.tolist()
m=int(max(set(result)))
for i in range(0,m+1):
    print("故障类型",i,"的数量：", result.count(i))
# Out:
# 32/32 [==============================] - 0s 2ms/step
# (1019, 4)
# 分类结果： [4 4 4 ... 4 4 4]
# 故障种类： 2
# 1019
# 故障类型 0 的数量： 0
# 故障类型 1 的数量： 0
# 故障类型 2 的数量： 0
# 故障类型 3 的数量： 1
# 故障类型 4 的数量： 1018

# %%
# 输入部分
train_DataFrame = pd.read_excel('./data_input/论文/实验/声音/训练.xlsx', header=None)


epochs = 30
lr = 3e-5
gamma = 0.7
seq_len = 12
patch_size = 1
num_classes = 4
dim = 32
depth = 6
heads = 8
mlp_dim = 64
dropout = 0.1
emb_dropout = 0.1

print('参数设置完成')
# Out:
# 参数设置完成

# %%
loss_m_csa,val_loss_m_csa,acc_m_csa,val_acc_m_csa=train_m_csa(seq_len,patch_size,num_classes,dim,depth,
                                                    heads,mlp_dim,dropout,emb_dropout,epochs,lr,gamma,train_DataFrame)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 619/619 [00:03<00:00, 181.31it/s]
# Epoch : 1 - loss : 0.9439 - acc: 0.6518 - val_loss : 0.6251 - val_acc: 0.7693
# 100%|███████████████████████████████████████████████████████████████████████████████| 619/619 [00:03<00:00, 170.81it/s]
# Epoch : 2 - loss : 0.5188 - acc: 0.8122 - val_loss : 0.4437 - val_acc: 0.8405
# 100%|███████████████████████████████████████████████████████████████████████████████| 619/619 [00:03<00:00, 176.63it/s]
# Epoch : 3 - loss : 0.4201 - acc: 0.8538 - val_loss : 0.3675 - val_acc: 0.8830
# 100%|███████████████████████████████████████████████████████████████████████████████| 619/619 [00:03<00:00, 176.67it/s]
# Epoch : 4 - loss : 0.3595 - acc: 0.8808 - val_loss : 0.3441 - val_acc: 0.8931
# 100%|███████████████████████████████████████████████████████████████████████████████| 619/619 [00:03<00:00, 174.61it/s]
# ...

# %%
print("m_csa参数部分")
print("训练损失：",loss_m_csa)
print("验证损失：",val_loss_m_csa)
print("训练-准确率：",acc_m_csa)
print("验证-准确率：",val_acc_m_csa)
# Out:
# csa参数部分
# 训练损失： [1.1038028001785278, 1.0732744932174683, 1.0520821809768677, 1.015792965888977, 0.9606066346168518, 0.9144299626350403, 0.8906655311584473, 0.8703736066818237, 0.853967547416687, 0.8405376076698303, 0.8298712968826294, 0.8188027143478394, 0.8051581382751465, 0.796762228012085, 0.7915868163108826, 0.772643506526947, 0.7587754726409912, 0.7484601140022278, 0.7360309958457947, 0.7257959246635437, 0.7151758670806885, 0.7036463618278503, 0.6972813010215759, 0.689167320728302, 0.6765512228012085, 0.6675780415534973, 0.6582303047180176, 0.6552605032920837, 0.6434621214866638, 0.6404345631599426]
# ...

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
m_csa_model = M_CSA(num_classes)
# data_path = './data_input/论文/实验/encode/声音/正常_验证.xlsx'
# data_path = './data_input/论文/实验/encode/声音/外圈_验证.xlsx'
# data_path = './data_input/论文/实验/encode/声音/内圈_验证.xlsx'
# data_path = './data_input/论文/实验/encode/声音/滚动体_验证.xlsx'
# 1、验证 正常_验证  1
# 2、验证 外圈_验证  2
# 3、验证 内圈_验证  3
# test_loader = data_loader(data_path, 1)
# test_loader = data_loader(data_path, 2)
# test_loader = data_loader(data_path, 3)
# test_loader = data_loader(data_path, 4)
m_csa_model.load_state_dict(torch.load('./saved_model/encode_model/m_csa/m_csa_model_parameters.pth'))
epoch_loss, epoch_acc, result = test_m_csa(m_csa_model, epochs, nn.CrossEntropyLoss(), test_loader, device)
print(f"loss : {epoch_loss:.4f} - acc: {epoch_acc:.4f}\n")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 797.58it/s]
# ...

# %%
loss_m_csa,val_loss_m_csa,acc_m_csa,val_acc_m_csa=train_m_csa(seq_len,patch_size,num_classes,dim,depth,
                                                    heads,mlp_dim,dropout,emb_dropout,epochs,lr,gamma,train_DataFrame)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 224.11it/s]
# Epoch : 1 - loss : 1.0490 - acc: 0.5119 - val_loss : 0.9996 - val_acc: 0.6170
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 231.48it/s]
# Epoch : 2 - loss : 0.9621 - acc: 0.5900 - val_loss : 0.9077 - val_acc: 0.6584
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 239.53it/s]
# Epoch : 3 - loss : 0.8499 - acc: 0.6466 - val_loss : 0.7593 - val_acc: 0.7144
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 242.96it/s]
# Epoch : 4 - loss : 0.6892 - acc: 0.7356 - val_loss : 0.5926 - val_acc: 0.8074
# 100%|███████████████████████████████████████████████████████████████████████████████| 200/200 [00:00<00:00, 237.72it/s]
# ...

# %%
print("m_csa参数部分")
print("训练损失：",loss_m_csa)
print("验证损失：",val_loss_m_csa)
print("训练-准确率：",acc_m_csa)
print("验证-准确率：",val_acc_m_csa)
# Out:
# m_csa参数部分
# 训练损失： [1.0489646196365356, 0.9621165990829468, 0.8499249219894409, 0.6892022490501404, 0.586467981338501, 0.5056116580963135, 0.454008013010025, 0.428975909948349, 0.38427168130874634, 0.37316781282424927, 0.34034228324890137, 0.3130241334438324, 0.31209057569503784, 0.2930088937282562, 0.27611279487609863, 0.2766275703907013, 0.25722265243530273, 0.24839408695697784, 0.2420889139175415, 0.23549237847328186, 0.22856512665748596, 0.22795283794403076, 0.20763298869132996, 0.2140512615442276, 0.1874396651983261, 0.1956653594970703, 0.1761157214641571, 0.19381332397460938, 0.17866720259189606, 0.2027559131383896]
# ...

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
m_csa_model = M_CSA(num_classes)
# data_path = './data_input/20/声音/正常_验证.xlsx'
# data_path = './data_input/20/声音/外圈_验证.xlsx'
# data_path = './data_input/20/声音/内圈_验证.xlsx'

# 1、验证 正常_验证  1
# 2、验证 外圈_验证  2
# 3、验证 内圈_验证  3
test_loader = data_loader(data_path, 1)
# test_loader = data_loader(data_path, 2)
# test_loader = data_loader(data_path, 3)

m_csa_model.load_state_dict(torch.load('./saved_model/model/m_csa/m_csa_model_parameters.pth'))
epoch_loss, epoch_acc, result = test_m_csa(m_csa_model, epochs, nn.CrossEntropyLoss(), test_loader, device)
print(f"loss : {epoch_loss:.4f} - acc: {epoch_acc:.4f}\n")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 621.04it/s]
# ...

# %%
loss_vit, val_loss_vit, acc_vit, val_acc_vit = train_ViT(seq_len, patch_size, num_classes, dim, depth, heads, 
                                                         mlp_dim, dropout, emb_dropout, epochs, lr, gamma, train_DataFrame)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:07<00:00, 27.40it/s]
# Epoch : 1 - loss : 1.0754 - acc: 0.4069 - val_loss : 0.9670 - val_acc: 0.5531
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:07<00:00, 27.62it/s]
# Epoch : 2 - loss : 0.8300 - acc: 0.6416 - val_loss : 0.6891 - val_acc: 0.7231
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:07<00:00, 28.08it/s]
# Epoch : 3 - loss : 0.5676 - acc: 0.7816 - val_loss : 0.4834 - val_acc: 0.8147
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:07<00:00, 27.04it/s]
# Epoch : 4 - loss : 0.4423 - acc: 0.8366 - val_loss : 0.4089 - val_acc: 0.8517
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [00:07<00:00, 26.82it/s]
# ...

# %%
print("vit参数部分")
print("训练损失：",loss_vit)
print("验证损失：",val_loss_vit)
print("训练-准确率：",acc_vit)
print("验证-准确率：",val_acc_vit)
# Out:
# vit参数部分
# 训练损失： [1.0753530263900757, 0.8299522399902344, 0.567589282989502, 0.4422553479671478, 0.39130672812461853, 0.32694387435913086, 0.31682053208351135, 0.28226131200790405, 0.26009243726730347, 0.2605443298816681, 0.22085383534431458, 0.2128075510263443, 0.2149522751569748, 0.19650481641292572, 0.18872906267642975, 0.18349801003932953, 0.1742904633283615, 0.1630314141511917, 0.1601761281490326, 0.15166112780570984, 0.140720397233963, 0.15497130155563354, 0.13902400434017181, 0.12674997746944427, 0.13005685806274414, 0.12211339920759201, 0.10811282694339752, 0.09981057792901993, 0.11213568598031998, 0.10098753869533539]
# ...

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
v_csa_model = V_CSA()
vit_model = ViT(seq_len=seq_len,
    patch_size=patch_size,
    num_classes=num_classes,
    dim=dim,
    depth=depth,
    heads=heads,
    mlp_dim=mlp_dim,
    dropout=dropout,
    emb_dropout=emb_dropout).to(device)

# data_path = './data_input/20/振动/正常_验证.xlsx'
# data_path = './data_input/20/振动/外圈_验证.xlsx'
data_path = './data_input/20/振动/内圈_验证.xlsx'

# 1、验证 正常_验证  1
# 2、验证 外圈_验证  2
# 3、验证 内圈_验证  3
# test_loader = data_loader(data_path, 1)
# test_loader = data_loader(data_path, 2)
test_loader = data_loader(data_path, 3)

# 加载模型参数
v_csa_model.load_state_dict(torch.load('./saved_model/model/ViT/v_csa_model_parameters.pth'))
vit_model.load_state_dict(torch.load('./saved_model/model/ViT/vit_model_parameters.pth'))
epoch_loss, epoch_acc, result = test_VIT(v_csa_model, vit_model, epochs, nn.CrossEntropyLoss(), test_loader, device)
print(f"loss : {epoch_loss:.4f} - acc: {epoch_acc:.4f}\n")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 24/24 [00:00<00:00, 79.67it/s]
# ...
